# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('C://Users//Boby Sinha//OneDrive//Desktop//wine-clustering.csv')

# %%
df.head(10)
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
# 5    14.20        1.76  2.45          15.2        112           3.27
# 6    14.39        1.87  2.45          14.6         96           2.50
# 7    14.06        2.15  2.61          17.6        121           2.60
# 8    14.83        1.64  2.17          14.0         97           2.80
# 9    13.86        1.35  2.27          16.0         98           2.98
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
df.set_index('Alcohol',drop=True,inplace=True)
df.head(10)
# Out:
#          Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  Flavanoids  \
# Alcohol
# 14.23          1.71  2.43          15.6        127           2.80        3.06
# 13.20          1.78  2.14          11.2        100           2.65        2.76
# 13.16          2.36  2.67          18.6        101           2.80        3.24
# 14.37          1.95  2.50          16.8        113           3.85        3.49
# 13.24          2.59  2.87          21.0        118           2.80        2.69
# 14.20          1.76  2.45          15.2        112           3.27        3.39
# 14.39          1.87  2.45          14.6         96           2.50        2.52
# 14.06          2.15  2.61          17.6        121           2.60        2.51
# 14.83          1.64  2.17          14.0         97           2.80        2.98
# 13.86          1.35  2.27          16.0         98           2.98        3.15
#
#          Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  OD280  \
# Alcohol
# ...

# %%
df.tail(10)
# Out:
#          Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  Flavanoids  \
# Alcohol
# 13.58          2.58  2.69          24.5        105           1.55        0.84
# 13.40          4.60  2.86          25.0        112           1.98        0.96
# 12.20          3.03  2.32          19.0         96           1.25        0.49
# 12.77          2.39  2.28          19.5         86           1.39        0.51
# 14.16          2.51  2.48          20.0         91           1.68        0.70
# 13.71          5.65  2.45          20.5         95           1.68        0.61
# 13.40          3.91  2.48          23.0        102           1.80        0.75
# 13.27          4.28  2.26          20.0        120           1.59        0.69
# 13.17          2.59  2.37          20.0        120           1.65        0.68
# 14.13          4.10  2.74          24.5         96           2.05        0.76
#
#          Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  OD280  \
# Alcohol
# ...

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3,random_state=13)

# %%
model.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=13)

# %%
model.inertia_
# Out:
# 2370619.873989546

# %%
df['sum1']=model.predict(df)
df.head()
# Out:
#          Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  Flavanoids  \
# Alcohol
# 14.23          1.71  2.43          15.6        127           2.80        3.06
# 13.20          1.78  2.14          11.2        100           2.65        2.76
# 13.16          2.36  2.67          18.6        101           2.80        3.24
# 14.37          1.95  2.50          16.8        113           3.85        3.49
# 13.24          2.59  2.87          21.0        118           2.80        2.69
#
#          Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  OD280  \
# Alcohol
# 14.23                    0.28             2.29             5.64  1.04   3.92
# 13.20                    0.26             1.28             4.38  1.05   3.40
# 13.16                    0.30             2.81             5.68  1.03   3.17
# 14.37                    0.24             2.18             7.80  0.86   3.45
# 13.24                    0.39             1.82             4.32  1.04   2.93
#
# ...

# %%
df.columns
# Out:
# Index(['Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium', 'Total_Phenols',
#        'Flavanoids', 'Nonflavanoid_Phenols', 'Proanthocyanins',
#        'Color_Intensity', 'Hue', 'OD280', 'Proline', 'sum1'],
#       dtype='object')

# %%
new = {'age Black':5, 'age Hispanic':30, 'age Asian':40, 'Median Age':40,
       'Unemployment rate':7, 'Per capita income':21}
new_df = pd.DataFrame(new,index=["New Alcohol"])
new_df
# Out:
#              age Black  age Hispanic  age Asian  Median Age  \
# New Alcohol          5            30         40          40
#
#              Unemployment rate  Per capita income
# New Alcohol                  7                 21

# %%
df.groupby('sum1').mean()
# Out:
#       Malic_Acid       Ash  Ash_Alcanity   Magnesium  Total_Phenols  \
# sum1
# 0       2.504032  2.408065     19.890323  103.596774       2.111129
# 1       1.883404  2.426170     17.023404  105.510638       2.867234
# 2       2.494203  2.288551     20.823188   92.347826       2.070725
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# sum1
# 0       1.584032              0.388387         1.503387         5.650323
# 1       3.014255              0.285319         1.910426         5.702553
# 2       1.758406              0.390145         1.451884         4.086957
#
#            Hue     OD280      Proline
# sum1
# 0     0.883968  2.365484   728.338710
# 1     1.078298  3.114043  1195.148936
# 2     0.941159  2.490725   458.231884

# %%
sum_sq_dist = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(df)
    sum_sq_dist.append(km.inertia_)

# %%
plt.plot(K, sum_sq_dist, 'r--')
plt.xlabel('Number of Clusters')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k');
